# %%
import pandas as pd
import random 
import numpy as np

filename = 'data/RAW20220307.csv'

df = pd.read_csv(filename)

# %%
setODT = set(list([(o, d, date, hour) for o, d, date, hour in zip(df['origin_station_name'], df['destination_station_name'], df['origin_date'], df['hour_'])]))

# %%
useful_vars = ['origin_station_name', 'destination_station_name', 'origin_date', 'hour_', 'normal_ratio', 'eld_ratio', 'transfer_time', 'avg_time', 'full_price', 'via_stations', 'hourly_cnt', 'od_ratio']

static_vars = ['hour_', 'normal_ratio', 'eld_ratio']

dict_vars_map1 = {'transfer_time': 'transfer_time1',
                  'avg_time': 'avg_time1',
                  'full_price': 'full_price1', 
                  'via_stations': 'via_stations1', 
                  'hourly_cnt': 'hourly_cnt1',
                  'od_ratio': 'od_ratio1'
                  }

dict_vars_map2 = {'transfer_time': 'transfer_time2', 
                  'avg_time': 'avg_time2', 
                  'full_price': 'full_price2', 
                  'via_stations': 'via_stations2', 
                  'hourly_cnt': 'hourly_cnt2', 
                  'od_ratio': 'od_ratio2'
                  }

dict_vars_map3 = {'transfer_time': 'transfer_time3',  
                  'avg_time': 'avg_time3', 
                  'full_price': 'full_price3', 
                  'via_stations': 'via_stations3', 
                  'hourly_cnt': 'hourly_cnt3', 
                  'od_ratio': 'od_ratio3'
                  }

dict_vars_map4 = {'transfer_time': 'transfer_time4',  
                  'avg_time': 'avg_time4', 
                  'full_price': 'full_price4', 
                  'via_stations': 'via_stations4', 
                  'hourly_cnt': 'hourly_cnt4', 
                  'od_ratio': 'od_ratio4'
                  }

dict_vars_map5 = {'transfer_time': 'transfer_time5',  
                  'avg_time': 'avg_time5', 
                  'full_price': 'full_price5', 
                  'via_stations': 'via_stations5', 
                  'hourly_cnt': 'hourly_cnt5', 
                  'od_ratio': 'od_ratio5'
                  }

listDictVarsMap = [dict_vars_map1, dict_vars_map2, dict_vars_map3, dict_vars_map4, dict_vars_map5]

# %%
len(setODT)
# Out:
# 11476

# %%
listDfAll = []

count = 0
for odt in setODT:
    o, d, date, hour = odt
    dfTemp = df[(df['origin_station_name']==o) & (df['destination_station_name']==d) & (df['origin_date']==date) & (df['hour_']==hour)]
    n = dfTemp.shape[0]
    if n > 1:
        n_idx_shuffle = np.arange(1,n+1)
        np.random.shuffle(n_idx_shuffle)
        listDfTemp = [dfTemp[dfTemp['cnt_rnk']==n_idx_shuffle[i]][useful_vars].rename(columns=listDictVarsMap[i]) for i in range(n)]
        dfAll = listDfTemp[0]

        for i in range(1, n):
            dfAll = pd.merge(dfAll,listDfTemp[i], on=['origin_station_name', 'destination_station_name', 'origin_date', 'hour_', 'normal_ratio', 'eld_ratio'])
        listDfAll.append(dfAll)
        
        count += 1
        print(count)

dfDatasets = pd.concat(listDfAll, axis=0) #.to_csv('check.csv')

# %%
dfDatasets
# Out:
#    origin_station_name destination_station_name origin_date  hour_  \
# 0                基立下道站                    江湾桥脚站  2022-03-07      9
# 0                江南新村站                   宝岗大道中站  2022-03-07     20
# 0      百越广场西门站（地铁市桥站）站                    富豪山庄站  2022-03-07     18
# 0                 天平架站                  南华工商学院站  2022-03-07     18
# 0                 中山医站                     农讲所站  2022-03-07     17
# ..                 ...                      ...         ...    ...
# 0                松柏东街站                    越秀公园站  2022-03-07      8
# 0                  江高站                      塘贝站  2022-03-07     17
# 0                 三元里站              三元里大道（桂花岗）站  2022-03-07     10
# 0                江南西路站                   海珠区妇幼站  2022-03-07     19
# 0               宝岗大道中站                     南田西站  2022-03-07     12
#
#     normal_ratio  eld_ratio  transfer_time1  avg_time1  full_price1  \
# 0       0.550000   0.450000               0   8.283000          2.0
# 0       0.263158   0.736842               0   3.650000          1.2
# 0       0.925926   0.074074               0  14.497867          2.0
# 0       0.952381   0.047619               0   6.016667          3.0
# 0       0.638889   0.361111               0  10.252357          1.0
# ..           ...        ...             ...        ...          ...
# 0       0.666667   0.333333               0  13.583333          1.2
# 0       0.944444   0.055556               0  11.507000          2.0
# 0       0.777778   0.222222               0   1.417000          2.0
# 0       0.812500   0.187500               0   6.077889          2.0
# 0       0.105263   0.894737               0   2.959222          0.0
#
#     via_stations1  ...  full_price4  via_stations4  hourly_cnt4  od_ratio4  \
# 0             2.0  ...          2.0            2.0          4.0   0.230769
# 0             2.0  ...          0.0            2.0          6.0   0.071429
# 0             5.0  ...          NaN            NaN          NaN        NaN
# 0             2.0  ...          1.0            1.0          3.0   0.166667
# 0             3.0  ...          2.0            3.0          4.0   0.034483
# ..            ...  ...          ...            ...          ...        ...
# 0             4.0  ...          NaN            NaN          NaN        NaN
# 0             5.0  ...          NaN            NaN          NaN        NaN
# 0             1.0  ...          2.0            1.0         14.0   0.636364
# 0             2.0  ...          NaN            NaN          NaN        NaN
# 0             1.0  ...          NaN            NaN          NaN        NaN
#
#     transfer_time5  avg_time5  full_price5  via_stations5  hourly_cnt5  \
# 0              0.0     8.2665          2.0            2.0          4.0
# 0              0.0     3.4415          2.0            2.0          9.0
# 0              NaN        NaN          NaN            NaN          NaN
# 0              0.0     3.8334          1.0            2.0          6.0
# 0              NaN        NaN          NaN            NaN          NaN
# ..             ...        ...          ...            ...          ...
# 0              NaN        NaN          NaN            NaN          NaN
# 0              NaN        NaN          NaN            NaN          NaN
# 0              NaN        NaN          NaN            NaN          NaN
# 0              NaN        NaN          NaN            NaN          NaN
# 0              NaN        NaN          NaN            NaN          NaN
#
#     od_ratio5
# 0    0.153846
# 0    0.142857
# 0         NaN
# 0    0.208333
# 0         NaN
# ..        ...
# 0         NaN
# 0         NaN
# 0         NaN
# 0         NaN
# 0         NaN
#
# [9203 rows x 36 columns]

# %%
dfTruth = dfDatasets[['origin_station_name', 'destination_station_name', 'origin_date', 'hour_', 'od_ratio1', 'od_ratio2', 'od_ratio3', 'od_ratio4', 'od_ratio5']]
dfTruth

dfTrain = dfDatasets.drop(columns=['origin_station_name', 'destination_station_name', 'origin_date', 'od_ratio1', 'od_ratio2', 'od_ratio3', 'od_ratio4', 'od_ratio5'])
dfTrain = dfTrain.fillna(-1)
dfTrain.to_csv('train_set.csv')

# %%
dfTruth.to_csv('truth.csv')
