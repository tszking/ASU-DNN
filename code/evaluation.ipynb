# %%
import pandas as pd
import numpy as np

# %%
dfTrue = pd.read_csv('y_test.csv', index_col=False)
dfTrue = dfTrue.iloc[: , 1:]
dfPredict = pd.read_csv('test_result.csv', index_col=False)
dfPredict = dfPredict.iloc[:, 1:]

# %%
npTrue = dfTrue.values.flatten()
npPredict = dfPredict.values.flatten()

# %%
npTrueFilter = npTrue[npTrue!=0]
npPredictFilter = npPredict[npTrue!=0]

# %%
mae = np.mean(np.absolute((npTrueFilter.astype("float") - npPredictFilter.astype("float"))))

# %%
mae
# Out:
# 8.329903217382856

# %%
np.mean(npTrueFilter,axis=0)
# Out:
# 21.07677124454602

# %%
dfTrain = pd.read_csv('train_set.csv')

# %%
dfTrain
# Out:
#        Unnamed: 0  hour_  normal_ratio  eld_ratio  total_cnt  transfer_time1  \
# 0               0     19      0.980952   0.014286      187.0             0.0
# 1               0      9      0.843972   0.156028       63.0             0.0
# 2               0      9      0.988506   0.011494       83.0             0.0
# 3               0     10      0.716049   0.283951       62.0             0.0
# 4               0      8      0.880000   0.120000       56.0             0.0
# ...           ...    ...           ...        ...        ...             ...
# 60318           0     17      0.975309   0.024691       84.0             0.0
# 60319           0     10      0.181818   0.818182       52.0             0.0
# 60320           0     11      0.985915   0.014085      124.0             0.0
# 60321           0     16      0.968421   0.031579       57.0            99.0
# 60322           0      8      0.983373   0.016627      100.0             0.0
#
# ...
